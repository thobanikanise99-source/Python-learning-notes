# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd # To perform data processing 
import numpy as np # To perform mathematical calculations

# %% [markdown]
# ### Data Ingestion

# %%
# Data path - Location of the data
data_path = "/Workspace/Users/rofhiwa@brightlearn.co.za/retail_sales_dataset.csv"

# %%
# Reading the data 
df=pd.read_csv(data_path)

# %% [markdown]
# ### Data Exploration

# %%
# Shows the first 10 rows in the data
df.head(10)
# Out:
#    Transaction ID        Date  ... Price per Unit Total Amount
# 0               1  2023-11-24  ...             50          150
# 1               2  2023-02-27  ...            500         1000
# 2               3  2023-01-13  ...             30           30
# 3               4  2023-05-21  ...            500          500
# 4               5  2023-05-06  ...             50          100
# 5               6  2023-04-25  ...             30           30
# 6               7  2023-03-13  ...             25           50
# 7               8  2023-02-22  ...             25          100
# 8               9  2023-12-13  ...            300          600
# 9              10  2023-10-07  ...             50          200
#
# [10 rows x 9 columns]

# %%
# Tell me the names of the columns in my dataset 
df.columns
# Out:
# Index(['Transaction ID', 'Date', 'Customer ID', 'Gender', 'Age',
#        'Product Category', 'Quantity', 'Price per Unit', 'Total Amount'],
#       dtype='object')

# %%
# Tell us the number of rows and number of columns in our data set (rows, columns)
df.shape
# Out:
# (1000, 9)

# %%
# Shows you the name of the column and the data type in each column
df.dtypes
# Out:
# Transaction ID       int64
# Date                object
# Customer ID         object
# Gender              object
# Age                  int64
# Product Category    object
# Quantity             int64
# Price per Unit       int64
# Total Amount         int64
# dtype: object

# %%
# This code is used to get the summary of your data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB

# %%
# This is used to count the number of null values
df.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64
